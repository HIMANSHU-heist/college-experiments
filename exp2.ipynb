# %%
import math

def circle_area(radius):
    return math.pi * radius * radius

def rectangle_area(length, width):
    return length * width

def triangle_area(base, height):
    return 0.5 * base * height



choice = input("Enter choice (1(circle)/2(rect)/3(square)): ")

if choice == '1':
    r = float(input("Enter radius: "))
    print("Area of Circle:", circle_area(r))

elif choice == '2':
    l = float(input("Enter length: "))
    w = float(input("Enter width: "))
    print("Area of Rectangle:", rectangle_area(l, w))

elif choice == '3':
    b = float(input("Enter base: "))
    h = float(input("Enter height: "))
    print("Area of Triangle:", triangle_area(b, h))

else:
    print("Invalid Input")
# Out:
# Area of Rectangle: 15.0

# %%
basic_salary = float(input("Enter Basic Salary: "))

da = 0.70 * basic_salary
ta = 0.30 * basic_salary
hra = 0.10 * basic_salary

gross_salary = basic_salary + da + ta + hra

print("Basic Salary: ", basic_salary)
print("Dearness Allowance (70%): ", da)
print("Travel Allowance (30%): ", ta)
print("House Rent Allowance (10%): ", hra)
print("----------------------------")
print("Gross Salary: ", gross_salary)
# Out:
# Basic Salary:  345546.0
# Dearness Allowance (70%):  241882.19999999998
# Travel Allowance (30%):  103663.8
# House Rent Allowance (10%):  34554.6
# ----------------------------
# Gross Salary:  725646.6

# %%
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

addition = num1 + num2
subtraction = num1 - num2
multiplication = num1 * num2
division = num1 / num2
modulus = num1 % num2
print("num1=",num1)
print("num2=",num2)
print("Addition:", addition)
print("Subtraction:", subtraction)
print("Multiplication:", multiplication)
print("Division:", division)
print("Modulus (Remainder):", modulus)
# Out:
# num1= 6.0
# num2= 2.0
# Addition: 8.0
# Subtraction: 4.0
# Multiplication: 12.0
# Division: 3.0
# Modulus (Remainder): 0.0
