# %%
def calculator(num1,num2,choice):
    if choice==1:
        return num1 + num2
    elif choice==2:
        return num1-num2
    elif choice==3:
        if num1 or num2 ==0:
            print(" plz enter valid number ")
        else:
            return num1/num2
    elif choice==4:
        return num1*num2
    else:
        print("plz enter valid operation")

print("1=addition,2=substraction,3=division,4=multiplication")
A=int(input("enter num1 : "))
B=int(input("enter num2 : "))
C=int(input("enter OPERATION(1,2 ETC,.) : "))
RESULT=calculator(A,B,C)
print(RESULT)
# Out:
# 1=addition,2=substraction,3=division,4=multiplication
# 5
