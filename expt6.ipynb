# %%
def divide_num():
    try:
        num1=float(input("enter first number"))
        num2=float(input("enter secod number"))
        result=num1/num2
    except ValueError:
        print("ërror please enter valid number")
    except ZeroDivisionError:
        print("error div by zero not allowed")

    else:
        print(f"the result  of dividing {num1} by {num2} is:{result}")
     
    finally:
        print("execution completed.")
divide_num()
# Out:
# the result  of dividing 8.0 by 4.0 is:2.0
# execution completed.

# %%
import pdb
import math
def calculate_area (radius):

    pi = 3.14
    return pi * radius ** 2

def calculate_circumference (radius):
    pi = 3.14

    return pi* radius **2
def main():
    radius  = 5

    area = calculate_area(radius)

    import pdb; pdb.set_trace()

    circumference = calculate_circumference (radius)

    print(f"Area: {area}")

    print(f"circumference: {circumference}")

main()

import math

def circle_calculation(radius):

    area = math.pi*radius*radius

    circumference =math.pi*radius

    return area, circumference

radius = float(input("Enetr radius:"))

a,c=circle_calculation(radius)

print("area of circle:",a)

print("circumference of circle:",c)
# Out:
# > /tmp/ipykernel_12433/3210270550.py(19)main()
#      17     import pdb; pdb.set_trace()
#      18
# ---> 19     circumference = calculate_circumference (radius)
#      20
#      21     print(f"Area: {area}")
#
# Area: 78.5
# circumference: 78.5
# area of circle: 78.53981633974483
# circumference of circle: 15.707963267948966
